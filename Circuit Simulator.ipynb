# %% [markdown]
# Example / playground jupyter notebook
#
# --- next moves ---
#
# - reduce print clutter, needs work in circuit.py

# %%
from noisiq.ir import Circuit, Operation


Test_circuit_1 = Circuit(
    n_qubits=2,
    ops=(Operation(name="x", qubits=(0,), t=0, meta={"x gate on 1st qubit" : True}),
         Operation(name="cx", qubits=(0, 1), t=1),
         Operation(name="x", qubits=(1,), t=2))
)

print(Test_circuit_1)
# Out:
# Circuit(n_qubits=2, ops=(Operation(name='x', qubits=(0,), t=0, meta={'x gate on 1st qubit': True}), Operation(name='cx', qubits=(0, 1), t=1), Operation(name='x', qubits=(1,), t=2)))

# %%
from noisiq.results import Frame, RunResult

f = Frame(t=0, phase="before", labels=["I", "I"], note="start")
r = RunResult(backend="dummy", seed=0, shots=1, frames=[f])

print(f)
print(r)
# Out:
# Frame(t=0, phase='before', labels=['I', 'I'], note='start')
# RunResult(backend='dummy', seed=0, shots=1, frames=[Frame(t=0, phase='before', labels=['I', 'I'], note='start')], stats=None, provenance=None)
